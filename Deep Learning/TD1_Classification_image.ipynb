# %% [markdown]
# # Lucie Drevet
# # César Leblanc
# # Stephan Adjarian
# # Alix Jacquemin
# # Inès Nguyen

# %% [markdown]
# # Week 1

# %% [markdown]
# ## Exe 1

# %%
try:
# %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception: 
  pass

# %% [markdown]
# ## Exe 2

# %%
from __future__ import absolute_import , division , print_function ,unicode_literals

# TensorFlow and tf. keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exe 3

# %%
print ( tf . __version__ )
# Out:
# 2.4.0

# %% [markdown]
# ## Exe 4

# %%
data = keras.datasets.cifar10
cifar10_data = data.load_data ()
# Out:
# ...
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
type(cifar10_data)
# Out:
# tuple

# %%
len(cifar10_data)
# Out:
# 2

# %%
cifar10_data[0:2]
# Out:
# ((array([[[[ 59,  62,  63],
#            [ 43,  46,  45],
#            [ 50,  48,  43],
#            ...,
#            [158, 132, 108],
#            [152, 125, 102],
#            [148, 124, 103]],
#
#           [[ 16,  20,  20],
#            [  0,   0,   0],
#            [ 18,   8,   0],
#            ...,
#            [123,  88,  55],
#            [119,  83,  50],
#            [122,  87,  57]],
#
#           [[ 25,  24,  21],
#            [ 16,   7,   0],
#            [ 49,  27,   8],
#            ...,
#            [118,  84,  50],
#            [120,  84,  50],
#            [109,  73,  42]],
#
#           ...,
#
#           [[208, 170,  96],
#            [201, 153,  34],
#            [198, 161,  26],
#            ...,
#            [160, 133,  70],
#            [ 56,  31,   7],
#            [ 53,  34,  20]],
#
#           [[180, 139,  96],
#            [173, 123,  42],
#            [186, 144,  30],
#            ...,
#            [184, 148,  94],
#            [ 97,  62,  34],
# ...

# %%
( train_images , train_labels ) ,( test_images , test_labels ) = cifar10_data
# Out:
# (50000, 1)

# %%
print ( train_images [0])
print ( train_images [0]. shape )
# Out:
# [[[ 59  62  63]
#   [ 43  46  45]
#   [ 50  48  43]
#   ...
#   [158 132 108]
#   [152 125 102]
#   [148 124 103]]
#
#  [[ 16  20  20]
#   [  0   0   0]
#   [ 18   8   0]
#   ...
#   [123  88  55]
#   [119  83  50]
#   [122  87  57]]
#
#  [[ 25  24  21]
#   [ 16   7   0]
#   [ 49  27   8]
#   ...
#   [118  84  50]
#   [120  84  50]
#   [109  73  42]]
#
#  ...
#
#  [[208 170  96]
#   [201 153  34]
#   [198 161  26]
#   ...
#   [160 133  70]
#   [ 56  31   7]
#   [ 53  34  20]]
#
#  [[180 139  96]
#   [173 123  42]
#   [186 144  30]
#   ...
#   [184 148  94]
#   [ 97  62  34]
#   [ 83  53  34]]
#
#  [[177 144 116]
#   [168 129  94]
#   [179 142  87]
#   ...
#   [216 184 140]
#   [151 118  84]
#   [123  92  72]]]
# (32, 32, 3)

# %%
class_names = [ 'airplane ' , 'automobile ' , 'bird ' , 'cat ' , 'deer ', 'dog ' , 'frog ' , 'horse ' , 'ship ' , 'truck ']

# %%
len(class_names)
# Out:
# 10

# %%
index = 8
plt . figure ()
plt . imshow ( train_images [ index ])
plt . colorbar ()
plt . grid ( False )
plt . show ()

train_labels [ index ]
# Out:
# array([8], dtype=uint8)

# %%
fig=plt.figure(figsize=(40, 40))
for i in range(25):
  fig.add_subplot(5, 5, i+1)
  plt.imshow (train_images [i])
  #plt.xlabel (train_images [i])
plt.show()

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
model = keras . Sequential ([
  keras.layers.Flatten ( input_shape =(32 , 32 , 3) ) ,
  keras . layers . Dense (128 , activation ='relu') ,
  keras.layers.Dense(64, activation='softplus'),
  keras . layers . Dense (10 , activation ='softmax' ) ])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten (Flatten)            (None, 3072)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               393344
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# ...
# Total params: 402,250
# Trainable params: 402,250
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile ( optimizer ='Adamax',
                  loss ='sparse_categorical_crossentropy',
                  metrics =['accuracy'])

# %%
model.fit(train_images , train_labels , epochs =10)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 2.0097 - accuracy: 0.2714
# Epoch 2/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.7502 - accuracy: 0.3805
# Epoch 3/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.6501 - accuracy: 0.4170
# Epoch 4/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.6041 - accuracy: 0.4328
# Epoch 5/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.5640 - accuracy: 0.4475
# Epoch 6/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.5318 - accuracy: 0.4580
# Epoch 7/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.5016 - accuracy: 0.4681
# Epoch 8/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.4827 - accuracy: 0.4739
# Epoch 9/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.4618 - accuracy: 0.4836
# Epoch 10/10
# ...

# %%
test_loss , test_acc = model . evaluate ( test_images , test_labels ,verbose =2)
# Out:
# 313/313 - 1s - loss: 1.4983 - accuracy: 0.4698

# %%
predictions = model.predict (test_images)
predictions[1]
# Out:
# array([2.5836507e-02, 3.0319867e-01, 2.7157965e-03, 1.2832840e-03,
#        8.0345728e-04, 6.6494959e-04, 2.9236195e-04, 3.3498980e-04,
#        2.8180444e-01, 3.8306561e-01], dtype=float32)

# %%
fig=plt.figure(figsize=(40, 40))
for i in range(3):
  fig.add_subplot(1, 3, i+1)
  plt.imshow (test_images [i])
  #plt.xlabel (train_images [i])
plt.show()

# %%
class_names[np.argmax(predictions[2])]
# Out:
# 'ship '

# %%
def prediction(index) :
  fig=plt.figure(figsize=(40, 40))
  fig, axs = plt.subplots(1, 1, constrained_layout=True)
  plt.imshow(test_images[index])
  col = 'red'
  if class_names[np.argmax(predictions[index])] == class_names[test_labels[index][0]]:
    col = 'blue'
  axs.set_title(class_names[np.argmax(predictions[index])]+str(max(predictions[index])*100), color = col)

prediction(0)

# %%
model.predict(np.expand_dims(test_images[5], axis =0))
#Input 0 of layer dense_3 is incompatible with the layer: expected axis -1 of input shape to have value 3072 but received input with shape (32, 96)
# Out:
# array([[1.6305661e-02, 2.6338592e-02, 6.2880188e-02, 2.2637907e-01,
#         2.8266920e-02, 9.4816737e-02, 4.9947426e-01, 1.4143542e-02,
#         3.5668607e-04, 3.1038389e-02]], dtype=float32)

# %%
data = keras . datasets . mnist
mnist_data = data . load_data ()
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step
